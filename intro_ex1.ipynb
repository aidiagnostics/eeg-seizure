# %% [markdown]
# # EEG signals, Seizure and Epilepsy
#
# ## Introduction
#
# In this notebook we show a procedure to upload EEG signals, show some graphs and apply some pre-processing. We used EEG recordings from the Siena Scalp EEG Database [1], which contains ...
#
# ## References
# 1. Database - https://physionet.org/content/siena-scalp-eeg/1.0.0/#files-panel
#
# ## Libraries Needed

# %%
import os
import mne
import numpy as np
import pandas as pd
from tqdm import tqdm
import matplotlib.pyplot as plt
## create separate pop-up windows for each figure
# %matplotlib qt

# %% [markdown]
# ## Functions Implemented

# %%
def vec_nor(x):
    """
    Normalize the amplitude of a vector from -1 to 1
    """
    nVec = np.zeros(len(x));		   # Initializate derivate vector
    nVec = np.divide(x, max(x))
    nVec = nVec-np.mean(nVec);
    nVec = np.divide(nVec,np.max(nVec));
        
    return nVec

# %% [markdown]
# ## Data Loading Process

# %%
# Reading and Plotting a single .edf file
edf_path = 'database\siena-scalp-eeg-database\PN00'
data = mne.io.read_raw_edf(edf_path + '\PN00-1.edf', preload=True)
# Out:
# Extracting EDF parameters from C:\Users\kevin\Desktop\Folder\EEG-tech-projects\Epilepsy\database\siena-scalp-eeg-database\PN00\PN00-1.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 1343999  =      0.000 ...  2624.998 secs...

# %% [markdown]
# In order to explore the information contained in the file, we simply used *.info*

# %%
print(data.info)
# Out:
# <Info | 7 non-empty values
#  bads: []
#  ch_names: EEG Fp1, EEG F3, EEG C3, EEG P3, EEG O1, EEG F7, EEG T3, EEG T5, ...
#  chs: 35 EEG
#  custom_ref_applied: False
#  highpass: 1.6 Hz
#  lowpass: 30.0 Hz
#  meas_date: 2016-01-01 19:39:33 UTC
#  nchan: 35
#  projs: []
#  sfreq: 512.0 Hz
# >

# %% [markdown]
# We can plot the whole data using the argument *.plot()* from the mne dataframe

# %%
data.plot()
